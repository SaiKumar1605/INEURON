# %% [markdown]
# <b>Author/User:</b> <b style="color:#6666ff">Sai Kumar Ramagiri</b><br>
# <b>Date of Submission:</b> <b style="color:#e69900">03/4/2023</b><br>

# %% [markdown]
# <u><h1 style="color:#006699; text-align:center">PYTHON BASICS</h1></u>

# %% [markdown]
# <u><h2 style="color:#24478f; text-align:center">ASSIGNMENT 14</h2></u>

# %% [markdown]
# <h4 style=" color: #ff3300">Q1. What does RGBA stand for?</h4>
#
# <b style ="color: #00b386">Answer:</b>
# <p>RGBA stands for Red-Green-Bue-Alpha</p>

# %% [markdown]
# <h4 style=" color: #ff3300">Q2. From the Pillow module, how do you get the RGBA value of any images?</h4>
#
# <b style ="color: #00b386">Answer:</b>
# <p>Following code is used to get RGBA values of image:</p>

# %%
from PIL import Image

# %%
img = Image.open('test.png')
#img.show()
display(img.convert('RGBA'))
# Out:
# <PIL.Image.Image image mode=RGBA size=180x263 at 0x13527FB4D88>

# %%
#This line gives the RGBA values of image
set(img.getdata())
# Out:
# {(0, 88, 248, 144),
#  (0, 72, 176, 61),
#  (0, 0, 128, 37),
#  (0, 72, 216, 186),
#  (0, 104, 248, 189),
#  (0, 84, 248, 238),
#  (0, 0, 248, 20),
#  (0, 32, 216, 23),
#  (0, 124, 248, 192),
#  (0, 92, 248, 86),
#  (16, 0, 248, 222),
#  (0, 108, 224, 56),
#  (0, 120, 248, 27),
#  (0, 128, 248, 241),
#  (0, 48, 224, 55),
#  (0, 36, 192, 70),
#  (0, 100, 248, 113),
#  (0, 112, 224, 36),
#  (0, 68, 248, 167),
#  (0, 80, 248, 255),
#  (0, 124, 240, 114),
#  (0, 16, 248, 91),
#  (0, 112, 216, 130),
#  (0, 72, 232, 118),
#  (0, 108, 248, 201),
#  (0, 120, 240, 29),
#  (0, 44, 72, 23),
#  (0, 80, 232, 219),
#  (0, 0, 40, 17),
#  (0, 88, 184, 57),
#  (72, 0, 248, 52),
#  (0, 56, 248, 110),
#  (80, 0, 248, 233),
#  (0, 88, 232, 220),
#  (0, 132, 248, 79),
#  (0, 108, 208, 68),
#  (0, 96, 184, 44),
#  (0, 92, 248, 182),
#  (0, 100, 200, 37),
#  (8, 0, 248, 25),
#  (0, 20, 144, 12),
#  (0, 100, 248, 232),
#  (0, 120, 248, 251),
#  (0, 68, 248, 30),
#  (0, 128, 248, 81),
#  (0, 76, 248, 102),
# ...

# %% [markdown]
# <h4 style=" color: #ff3300">Q3. What is a box tuple, and how does it work?</h4>
#
# <b style ="color: #00b386">Answer:</b>
# <p>Box tuple is a tuple of four integer coordinates that represent a rectanguar region in a image. Those four integers indicate <b>eft,Top,Right,Bottom</b></p>
# <p>Example: <b> (3,1,9,6)</b></p>
# <img src='box_tuple.jpg'>

# %% [markdown]
# <h4 style=" color: #ff3300">Q4. Use your image and load in notebook then, How can you find out the width and height of an
# Image object?</h4>
#
# <b style ="color: #00b386">Answer:</b>

# %%
img = Image.open('test.png')
display(img)

#width and height of image
img.size
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=180x263 at 0x13528093F48>
# (180, 263)

# %% [markdown]
# <h4 style=" color: #ff3300">Q5. What method would you call to get Image object for a 100×100 image, excluding the lower-left
# quarter of it?</h4>
#
# <b style ="color: #00b386">Answer:</b>
# <p><b>img.crop()</b> method is used ti get image object for a 100x100 image, excuding the lower-left quarter of it.</p>

# %%
ic = img.crop((0,163,100,263))
ic
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100 at 0x135280BF648>

# %% [markdown]
# <h4 style=" color: #ff3300">Q6. After making changes to an Image object, how could you save it as an image file?</h4>
#
# <b style ="color: #00b386">Answer:</b>
# <p><b>img.save()</b> method is save the image object.</p>

# %%
ic.save('save_img.png')

# %% [markdown]
# <h4 style=" color: #ff3300">Q7. What module contains Pillow’s shape-drawing code?</h4>
#
# <b style ="color: #00b386">Answer:</b>
# <p><b>ImageDraw</b> module from PIL package contains pillow's shape-drawing code.</p>

# %%
from PIL import ImageDraw

# %% [markdown]
# <h4 style=" color: #ff3300">Q8. Image objects do not have drawing methods. What kind of object does? How do you get this kind
# of object?</h4>
#
# <b style ="color: #00b386">Answer:</b>
# <p><b>ImageDraw</b> module objects from Pilows package can be used to create simple 2D graphics on image objects.</p>

# %%
img = Image.open('test.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=180x263 at 0x1352A61BB08>

# %%
draw = ImageDraw.Draw(img)
draw.line((0,0) + img.size, fill=128)

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=180x263 at 0x1352A61BB08>
